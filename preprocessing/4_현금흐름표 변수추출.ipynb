# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/프로젝트/DART/2021_사업보고서_04_현금흐름표.csv', encoding='cp949')

# %%
df
# Out:
#                      재무제표종류      종목코드 회사명       시장구분   업종            업종명  결산월  \
# 0       현금흐름표. 간접법 - 별도재무제표  [060310]  3S  코스닥시장상장법인  292  특수 목적용 기계 제조업    3
# 1       현금흐름표. 간접법 - 별도재무제표  [060310]  3S  코스닥시장상장법인  292  특수 목적용 기계 제조업    3
# 2       현금흐름표. 간접법 - 별도재무제표  [060310]  3S  코스닥시장상장법인  292  특수 목적용 기계 제조업    3
# 3       현금흐름표. 간접법 - 별도재무제표  [060310]  3S  코스닥시장상장법인  292  특수 목적용 기계 제조업    3
# 4       현금흐름표. 간접법 - 별도재무제표  [060310]  3S  코스닥시장상장법인  292  특수 목적용 기계 제조업    3
# ...                     ...       ...  ..        ...  ...            ...  ...
# 103326  현금흐름표. 직접법 - 별도재무제표  [238490]  힘스  코스닥시장상장법인  292  특수 목적용 기계 제조업   12
# 103327  현금흐름표. 직접법 - 별도재무제표  [238490]  힘스  코스닥시장상장법인  292  특수 목적용 기계 제조업   12
# 103328  현금흐름표. 직접법 - 별도재무제표  [238490]  힘스  코스닥시장상장법인  292  특수 목적용 기계 제조업   12
# 103329  현금흐름표. 직접법 - 별도재무제표  [238490]  힘스  코스닥시장상장법인  292  특수 목적용 기계 제조업   12
# 103330  현금흐름표. 직접법 - 별도재무제표  [238490]  힘스  코스닥시장상장법인  292  특수 목적용 기계 제조업   12
#
# ...

# %%
df.columns
# Out:
# Index(['재무제표종류', '종목코드', '회사명', '시장구분', '업종', '업종명', '결산월', '결산기준일', '보고서종류',
#        '통화', '항목코드', '항목명', ' 당기 ', ' 전기 ', ' 전전기 '],
#       dtype='object')

# %% [markdown]
# ## 이자비용
# - 항목코드 : dart_AdjustmentsForInterestExpenses

# %%
#이자비용행만 추출
df_1 = df[(df['항목코드']=='dart_AdjustmentsForInterestExpenses')|(df['항목명']=='이자비용')|(df['항목명']=='      이자비용')|(df['항목명']=='   이자비용')|(df['항목명']=='      금융원가(이자비용)')|
          (df['항목명']=='         이자비용')|(df['항목명']=='      금융원가-이자비용')|(df['항목명']=='      금융원가 (이자비용)')]


#행 이름 변경
df_1.columns = ['재무제표종류', '종목코드', '회사명', '시장구분', '업종', '업종명', '결산월', '결산기준일', '보고서종류',
       '통화', '항목코드', '항목명', '이자비용_당기', '이자비용_전기', '이자비용_전전기']


#필요한 행만 데이터프레임 생성
df_1 = df_1[['회사명', '이자비용_당기', '이자비용_전기', '이자비용_전전기']]

# %%
df_1
# Out:
#                회사명           이자비용_당기           이자비용_전기          이자비용_전전기
# 8               3S      455,470,086       389,323,187       780,283,868
# 233           AP위성        7,871,307         7,907,696         6,387,616
# 533         CJ CGV   22,097,632,177    14,409,241,873    15,768,750,908
# 682     CJ 바이오사이언스    4,922,249,853     1,622,295,196        45,331,085
# 894          CMG제약       20,695,372        22,852,791         8,593,275
# ...            ...               ...               ...               ...
# 102337        휴마시스      116,349,870       265,781,943       799,177,008
# 102578         휴비스    3,955,897,570     7,292,262,102     7,959,602,380
# 102739         휴스틸    2,503,614,089     2,848,209,060     4,146,221,891
# 102980         휴켐스    1,877,292,292     2,354,139,301     3,347,367,941
# 103112          흥국      131,637,947       168,374,867       253,374,836
#
# [544 rows x 4 columns]

# %%
df_1.to_csv('현금흐름표 변수추출.csv', encoding='utf-8-sig')
